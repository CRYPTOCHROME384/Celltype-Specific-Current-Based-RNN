# %%
import os
from os import listdir
from os.path import isfile, join
import pickle
from utils import *
import json 
import matplotlib.pyplot as plt
from losses import *
from model import  SingleTrialLicks 

#stitch all sessions
path_dandi= '../data/MAPDANDI_Functional/'
directory = os.fsencode(path_dandi)
files_list = []
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename[30:31]=='.':
        data = pickle.load(open(path_dandi+filename, 'rb'))
        if len(data)>0:
            n_neurons = data['average_trials'].shape[1]
            if n_neurons>0:
                files_list.append(filename)

#loading hiperparameters data
with open('parameters_list.json') as f:
    default_parameters = json.load(f)

n_pop = 12
net = None#'net_ALM_hemi_right8.pth'
hemi = 'right' #training on just left hemisphere neurons
max_epochs = 4
lr=5e-4
c_av = 0.7
c_orth = 500
c_sel = 0.5
test_every = 50
optimize_every = 1


#loading data  
max_time_index = 275 
mean_licks = mean_licks_inputs(files_list, hemi = hemi, max_time_index = max_time_index) 
single_trial_licks = licks_inputs(files_list, max_time_index =  max_time_index)
ALM_hemi= load_me_data(files_list, default_parameters, hemi=hemi, max_time_index=max_time_index)
trial_average = tch.tensor(ALM_hemi['rates'][0:2,:,:], dtype = tch.float32).to(default_parameters['device']).float()
print('dimensions', hemi, trial_average.shape, mean_licks.shape)

# %%
session_names = ['sub-456772_ses-20191120T115527.p']
#loading data    
total_sessions = len(session_names)
trial_indexes = {}
for ses_name in session_names:
    trial_indexes[ses_name] = ALM_hemi['indexes'][ses_name]
trial_average, trial_types = toch_version_ratates_trial_types(ALM_hemi, default_parameters, session_names)


indexes_neurons_st = [ALM_hemi['indexes'][s] for s in session_names]
total_sessions = len(indexes_neurons_st )
st_licks = tch.zeros(single_trial_licks[session_names[0]].shape)


default_parameters['n_latents'] = n_pop
default_parameters['n_neurons'] = ALM_hemi['rates'].shape[2]


#trial average
LossTrials = LossAverageTrials()
losses_trial_av = np.zeros(max_epochs)
#loss on the modes
LossSelectivity = SelectivityLoss(trial_average, default_parameters)
losses_sel = np.zeros(max_epochs)
#loss on the orthogonality of the weights
LossWeights = LossOrthogonality(default_parameters['device']) 
losses_weights = np.zeros(max_epochs)
losses_time_av = np.zeros(max_epochs)
losses_neurons_av = np.zeros(max_epochs)
#Defining losses
#average over time
ListLossesTime = [LossAverageTime(ALM_hemi['indexes'][s], default_parameters) for s in session_names]
#average over neurons
ListLossesNeurons = [LossAverageNeurons(ALM_hemi['indexes'][s]) for s in session_names]


n_trials = 0
for t_type in trial_types:
    n_trials+=len(trial_types[t_type])
default_parameters['n_trials'] = n_trials
net = SingleTrialLicks(default_parameters, indexes_neurons_st)
net.device = default_parameters['device']


epoch=0
min_mean_loss = 10. 
thres_trial_av = 10.
mean_loss = 100.
while epoch<1:
    #adding initial data
    results, cov = net.forward(mean_licks, single_trial_licks, trial_types)
    #Reconsutring neural activity average over trials
    total_trial_average = LossTrials(trial_average, results['rates_alm'])
    losses_trial_av[epoch] = total_trial_average.detach().cpu().numpy()
    
    #Reconsutring average activity over time
    total_time_average = 0
    ind_trial = 0
    for s in range(len(session_names)):
    #trial indexes to compute
        ses_name = session_names[s]
        total_time_average += ListLossesTime[s](ALM_hemi['time_average'][ses_name], results['rates_trials'][:,:,indexes_neurons_st[s]])
        total_time_average = total_time_average/float(total_sessions)
        losses_time_av[epoch] = total_time_average .detach().cpu().numpy()
    epoch+=1
# Out:
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [0,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [2,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [4,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [6,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [8,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [10,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [12,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [14,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [16,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [18,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [20,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [22,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [24,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [26,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [28,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [30,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/conda/conda-bld/pytorch_1720538439675/work/aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [30,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 62
#      59 for s in range(len(session_names)):
#      60 #trial indexes to compute
#      61     ses_name = session_names[s]
# ---> 62     total_time_average += ListLossesTime[s](ALM_hemi['time_average'][ses_name], results['rates_trials'][:,:,indexes_neurons_st[s]])
#      63     total_time_average = total_time_average/float(total_sessions)
#      64     losses_time_av[epoch] = total_time_average .detach().cpu().numpy()
#
# File ~/capsule/code/losses.py:158, in LossAverageTime.__call__(self, av_time_data, rates)
#     156 def __call__(self, av_time_data, rates):
#     157     # mean spikes across neurons
# --> 158     av_time_model = self.compute_time_averages(rates)
#     159     #calculating losses
#     160     total_loss = tch.mean(tch.square(av_time_data - av_time_model))
#
# File ~/capsule/code/losses.py:164, in LossAverageTime.compute_time_averages(self, rates)
#     163 def compute_time_averages(self, rates):
# --> 164     average_sample = tch.sum(rates[:, self.ind_sample_s:self.ind_sample_e, self.indexes_neurons], axis = 1) * (self.dt/0.65) #spikes per s
#     165     average_delay = tch.sum(rates[:, self.ind_sample_e:self.ind_delay_e, self.indexes_neurons], axis = 1) * (self.dt/1.2) #spikes per s
#     166     average_response = tch.sum(rates[:, self.ind_delay_e:self.ind_response, self.indexes_neurons], axis = 1) * (self.dt/self.t_after_go) #spikes per s
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
path_dandi = '../data/MAPDANDI_Functional/'
data_bh = pickle.load(open(path_dandi+ 'sub-456772_ses-20191120T115527' + '_behavior.p', 'rb'))

# %%
licks = licks_inputs(files_list, max_time_index = 350, ind_start=50)

# %%
licks['sub-456772_ses-20191120T115527.p'].shape
# Out:
# torch.Size([2, 243, 350])

# %%
data_ses = load_me_data(['sub-456772_ses-20191120T115527.p'], default_parameters, hemi = 'left', max_time_index=350)

# %%
data_ses['n_trials']
# Out:
# array([243])

# %%
data_bh['inds_good_trials'].shape
# Out:
# (243,)

# %%
data_bh.keys()
# Out:
# dict_keys(['inds_left_hit', 'inds_right_hit', 'inds_good_trials', 'trial_type', 'trial_responses', 'time_left_licks', 'time_right_licks', 'rates_left_licks', 'rates_right_licks', 'jaw_time_series', 'nose_time_series', 'time_jaw', 'time_nose', 'bins'])

# %%
mean_licks.shape
# Out:
# torch.Size([2, 275, 4244])

# %%
single_trial_licks['sub-456772_ses-20191120T115527.p'].shape
# Out:
# torch.Size([2, 243, 275])

# %%
results['latents_trials'].shape
# Out:
# torch.Size([243, 275, 12])

# %%
ALM_hemi['neurons_average'][session_names[0]].shape
# Out:
# torch.Size([243, 435])

# %%
session_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 session_names
#
# NameError: name 'session_names' is not defined

# %%
ALM_hemi['time_average']['sub-456774_ses-20191021T142044.p'].shape
# Out:
# torch.Size([5, 236, 57])
